# %%
import json
import pandas as pd

with open('src/data/intern_project_data.json', 'r') as f:
    data = json.load(f)

# Convert each section to a DataFrame
bio_df = pd.DataFrame(data['bio'])
game_logs_df = pd.DataFrame(data['game_logs'])
season_logs_df = pd.DataFrame(data['seasonLogs'])
measurements_df = pd.DataFrame(data['measurements'])
scouting_df = pd.DataFrame(data['scoutingReports'])

# %%
# Basic structure
bio_df.head()
# Out:
#                   name  playerId firstName    lastName   birthDate  height  \
# 0         Cooper Flagg    170531    Cooper       Flagg  2006-12-21      81
# 1         Dylan Harper    161608     Dylan      Harper  2006-03-02      78
# 2           Ace Bailey    161710       Ace      Bailey  2006-08-13      82
# 3         VJ Edgecombe    181834        VJ   Edgecombe  2005-07-30      77
# 4  Kasparas Jakucionis    140378  Kasparas  Jakucionis  2006-05-29      78
#
#    weight                highSchool highSchoolState        homeTown homeState  \
# 0     209                 Montverde              FL    New Portland        ME
# 1     215  Don Bosco Preparatory HS              NJ  Franklin Lakes        NJ
# 2     210              McEachern HS              GA     Chattanooga        TN
# 3     188   Long Island Lutheran HS              NY      Alice Town      None
# 4     205                      None            None         Vilnius      None
#
#   homeCountry nationality                                           photoUrl  \
# 0         USA         USA  https://www.draftexpress.com/blue/images/heads...
# 1         USA         USA  https://www.draftexpress.com/blue/images/heads...
# 2         USA         USA                                               None
# 3     Bahamas     Bahamas  https://www.draftexpress.com/blue/images/heads...
# 4   Lithuania   Lithuania  https://www.draftexpress.com/blue/images/heads...
#
#   currentTeam    league leagueType
# 0        Duke  NCAA D-I       NCAA
# 1     Rutgers  NCAA D-I       NCAA
# 2     Rutgers  NCAA D-I       NCAA
# 3      Baylor  NCAA D-I       NCAA
# 4    Illinois  NCAA D-I       NCAA

# %%
# How many players total?
len(bio_df)
# Out:
# 60

# %%
# Check for missing data
measurements_df.isnull().sum()
# Out:
# playerId           0
# heightNoShoes      1
# heightShoes        0
# wingspan           1
# reach              1
# maxVertical        9
# noStepVertical     9
# weight             1
# bodyFat           54
# handLength         3
# handWidth          3
# agility           12
# sprint            12
# shuttleLeft       56
# shuttleRight      56
# shuttleBest       17
# dtype: int64

# %%
# Check for missing data
bio_df.isnull().sum()
# Out:
# name                0
# playerId            0
# firstName           0
# lastName            0
# birthDate           0
# height              0
# weight              0
# highSchool         15
# highSchoolState    19
# homeTown            0
# homeState          22
# homeCountry         0
# nationality         0
# photoUrl           12
# currentTeam         0
# league              0
# leagueType          0
# dtype: int64

# %%
# Which players have the most games logged?
game_logs_df['playerId'].value_counts().head(10)
# Out:
# playerId
# 99451     10
# 118028    10
# 123733    10
# 124543    10
# 129665    10
# 129693    10
# 130696    10
# 136466    10
# 138145    10
# 139181    10
# Name: count, dtype: int64

# %%
# Longest scouting reports
scouting_df['reportLength'] = scouting_df['report'].str.split().str.len()
scouting_df.sort_values('reportLength', ascending=False).head(5)
# Out:
#          scout                              reportId  playerId  \
# 0  Sam Vecenie  32fb9c99-733a-4f5a-8142-912c8aabb364    161710
# 1  Sam Vecenie  ed7bcf33-cf7b-4103-88ea-7eaadedd8a40    181834
# 2   Kyle Boone  6b682d97-ae9a-461a-b5e0-bb9a77b349b3    181834
# 3  Sam Vecenie  1c0702c5-4a24-404c-b2cc-343be16ae5a7    161852
# 4   Kyle Boone  03277a94-63a7-452f-a910-ea1c8c9029c0    164614
#
#                                               report  reportLength
# 0  Lorem ipsum dolor sit amet, consectetur adipis...            69
# 1  Lorem ipsum dolor sit amet, consectetur adipis...            69
# 2  Lorem ipsum dolor sit amet, consectetur adipis...            69
# 3  Lorem ipsum dolor sit amet, consectetur adipis...            69
# 4  Lorem ipsum dolor sit amet, consectetur adipis...            69

# %%
from collections import Counter

# Count both player's own team and opponent
team_counts = Counter()

for game in game_logs_df.to_dict(orient="records"):
    team_counts[game["team"]] += 1
    team_counts[game["opponent"]] += 1

# Convert to DataFrame and sort
most_common_teams = pd.DataFrame(team_counts.items(), columns=["Team", "Appearances"])
most_common_teams = most_common_teams.sort_values(by="Appearances", ascending=False)

most_common_teams.head(60)
# Out:
#                      Team  Appearances
# 27                   Duke           71
# 9                Arkansas           35
# 46         North Carolina           33
# 4             Connecticut           27
# 10             Texas Tech           26
# 83               Illinois           25
# 76                Florida           22
# 41                Houston           22
# 129               Rutgers           21
# 43                Arizona           20
# 90         Ratiopharm Ulm           20
# 87               Maryland           19
# 82               Kentucky           19
# 44                 Baylor           19
# 29                 Auburn           18
# 78               Michigan           18
# 48            Wake Forest           18
# 85               Oklahoma           17
# 80              Tennessee           17
# 0               Villanova           16
# 17                  Texas           16
# 77            Michigan St           15
# 6              Georgetown           15
# 14         South Carolina           15
# 36   South East Melbourne           14
# 8               Marquette           14
# 170               Georgia           14
# 28              Creighton           13
# 42                Alabama           13
# 49                Le Mans           12
# 68      Cedevita Olimpija           12
# 59               Valencia           12
# 32                 Sydney           12
# 130          San Diego St           12
# 97                 Vechta           12
# 40               Brisbane           11
# 19               Stanford           11
# 156        Saint Joseph's           11
# 157                   UAB           11
# 114           Colorado St           11
# 60            Real Madrid           11
# 50          Saint Quentin           11
# 69                    BYU           11
# 102              Joventut           10
# 146         Mega Superbet           10
# 173           Mexico City           10
# 183         Reggio Emilia           10
# 13            Mississippi           10
# 11             St. John's            9
# 18               Missouri            8
# 22             Louisville            8
# 88                   Iowa            8
# 47           Georgia Tech            7
# 5              Seton Hall            7
# 45          Mt. St. Marys            6
# 12                 Kansas            6
# 2                     USC            6
# 31                 Xavier            6
# 70              Wisconsin            6
# 191         Washington St            6

# %%
# Count how many players have each nationality
nationality_counts = bio_df['nationality'].value_counts()

# Convert to DataFrame for easy viewing
nationality_counts_df = nationality_counts.reset_index()
nationality_counts_df.columns = ['Nationality', 'Player Count']

# Show top 20
nationality_counts_df
# Out:
#             Nationality  Player Count
# 0                   USA            33
# 1                France             5
# 2             Australia             4
# 3                Israel             2
# 4                 Spain             2
# 5               Croatia             2
# 6    Dominican Republic             2
# 7                Russia             1
# 8               Bahamas             1
# 9                Canada             1
# 10            Lithuania             1
# 11          South Sudan             1
# 12                 Mali             1
# 13              Germany             1
# 14               Serbia             1
# 15              Senegal             1
# 16  Trinidad and Tobago             1
